# %%
# %sql

-- Grant the app's service principal access to read the Volume
GRANT USE CATALOG ON CATALOG `workspace` TO `b7959816-0330-4ac7-9396-ac05029c43b1`;
GRANT USE SCHEMA ON SCHEMA `workspace`.`default` TO `b7959816-0330-4ac7-9396-ac05029c43b1`;
GRANT READ VOLUME ON VOLUME `workspace`.`default`.`bharat_bricks_hacks` TO `b7959816-0330-4ac7-9396-ac05029c43b1`;
